# %% [markdown]
# <a href="https://colab.research.google.com/github/KuJoJot4ro/College-Python/blob/main/Python_Micro_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Tic Tac Toe Game**

# %%
def print_board(board):
    print("Current board:")
    for row in board:
        print(" | ".join(row))
        print("-" * 9)

def check_winner(board):
    # Check rows, columns and diagonals for a win
    for i in range(3):
        if board[i][0] == board[i][1] == board[i][2] != " ":
            return board[i][0]
        if board[0][i] == board[1][i] == board[2][i] != " ":
            return board[0][i]

    if board[0][0] == board[1][1] == board[2][2] != " ":
        return board[0][0]
    if board[0][2] == board[1][1] == board[2][0] != " ":
        return board[0][2]

    return None

def is_draw(board):
    return all(cell != " " for row in board for cell in row)

def tic_tac_toe():
    player1 = input("Enter the name of Player 1 (X): ")
    player2 = input("Enter the name of Player 2 (O): ")

    board = [[" " for _ in range(3)] for _ in range(3)]
    current_player = "X"
    current_player_name = player1

    while True:
        print_board(board)
        while True:
            try:
                row = int(input(f"{current_player_name}, enter the row (0-2): "))
                col = int(input(f"{current_player_name}, enter the column (0-2): "))
                if row < 0 or row > 2 or col < 0 or col > 2:
                    print("Invalid input. Please enter numbers between 0 and 2.")
                    continue
                if board[row][col] != " ":
                    print("Cell already taken. Choose another cell.")
                    continue
                break  # Valid input, exit the loop
            except ValueError:
                print("Invalid input. Please enter numbers between 0 and 2.")

        board[row][col] = current_player

        winner = check_winner(board)
        if winner:
            print_board(board)
            print(f"Player {current_player_name} wins!")
            break

        if is_draw(board):
            print_board(board)
            print("It's a draw!")
            break

        # Switch players
        if current_player == "X":
            current_player = "O"
            current_player_name = player2
        else:
            current_player = "X"
            current_player_name = player1

if __name__ == "__main__":
    tic_tac_toe()
# Out:
# Enter the name of Player 1 (X): Bob
# Enter the name of Player 2 (O): John
# Current board:
#   |   |
# ---------
#   |   |
# ---------
#   |   |
# ---------
# Bob, enter the row (0-2): 3
# Bob, enter the column (0-2): 3
# Invalid input. Please enter numbers between 0 and 2.
# Bob, enter the row (0-2): 1
# Bob, enter the column (0-2): 1
# Current board:
#   |   |
# ---------
#   | X |
# ---------
#   |   |
# ---------
# John, enter the row (0-2): 1
# John, enter the column (0-2): 2
# Current board:
#   |   |
# ---------
#   | X | O
# ---------
#   |   |
# ---------
# Bob, enter the row (0-2): 2
# Bob, enter the column (0-2): 0
# Current board:
#   |   |
# ---------
#   | X | O
# ---------
# X |   |
# ---------
# John, enter the row (0-2): 2
# John, enter the column (0-2): 0
# Cell already taken. Choose another cell.
# John, enter the row (0-2): 2
# John, enter the column (0-2): 0
# Cell already taken. Choose another cell.
# John, enter the row (0-2): 0
# John, enter the column (0-2): 2
# Current board:
#   |   | O
# ---------
#   | X | O
# ---------
# X |   |
# ---------
# Bob, enter the row (0-2): 2
# Bob, enter the column (0-2): 2
# Current board:
#   |   | O
# ---------
#   | X | O
# ---------
# X |   | X
# ---------
# John, enter the row (0-2): 0
# John, enter the column (0-2): 0
# Current board:
# O |   | O
# ---------
#   | X | O
# ---------
# X |   | X
# ---------
# Bob, enter the row (0-2): 1
# Bob, enter the column (0-2): 1
# Cell already taken. Choose another cell.
# Bob, enter the row (0-2): 2
# Bob, enter the column (0-2): 1
# Current board:
# O |   | O
# ---------
#   | X | O
# ---------
# X | X | X
# ---------
# Player Bob wins!

# %% [markdown]
# # **Hangman Game**

# %%
import random

def display_hangman(tries):
    stages = [
        """
           ------
           |    |
           |    O
           |   /|\\
           |   / \\
           |
        """,
        """
           ------
           |    |
           |    O
           |   /|\\
           |   /
           |
        """,
        """
           ------
           |    |
           |    O
           |   /|\\
           |
           |
        """,
        """
           ------
           |    |
           |    O
           |   /|
           |
           |
        """,
        """
           ------
           |    |
           |    O
           |    |
           |
           |
        """,
        """
           ------
           |    |
           |    O
           |
           |
           |
        """,
        """
           ------
           |    |
           |
           |
           |
           |
        """
    ]
    return stages[6 - tries]

def hangman():
    words = ["python", "hangman", "programming", "developer", "challenge"]
    word = random.choice(words)
    word_completion = "_" * len(word)
    guessed = False
    guessed_letters = []
    guessed_words = []
    tries = 6

    print("Welcome to Hangman!")
    print(display_hangman(tries))
    print(word_completion)
    print("\n")

    while not guessed and tries > 0:
        guess = input("Please guess a letter or word: ").lower()

        if len(guess) == 1 and guess.isalpha():
            if guess in guessed_letters:
                print("You already guessed that letter. Try again.")
            elif guess not in word:
                print(f"{guess} is not in the word.")
                tries -= 1
                guessed_letters.append(guess)
            else:
                print(f"Good job! {guess} is in the word.")
                guessed_letters.append(guess)
                word_completion = "".join([letter if letter in guessed_letters else "_" for letter in word])
                if "_" not in word_completion:
                    guessed = True
        elif len(guess) == len(word) and guess.isalpha():
            if guess in guessed_words:
                print("You already guessed that word. Try again.")
            elif guess != word:
                print(f"{guess} is not the word.")
                tries -= 1
                guessed_words.append(guess)
            else:
                guessed = True
                word_completion = word
        else:
            print("Invalid input. Please guess a letter or a word.")

        print(display_hangman(tries))
        print(word_completion)
        print("\n")
        print("Guessed letters:", " ".join(guessed_letters))
        print("Guessed words:", " ".join(guessed_words))

    if guessed:
        print(f"Congratulations! You've guessed the word: {word}!")
    else:
        print(f"Sorry, you've run out of tries. The word was: {word}.")

# Start the game
hangman()
# Out:
# Welcome to Hangman!
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# _________
#
#
# Please guess a letter or word: python
# Invalid input. Please guess a letter or a word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# _________
#
#
# Guessed letters:
# Guessed words:
# Please guess a letter or word: p
# Good job! p is in the word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# ______p__
#
#
# Guessed letters: p
# Guessed words:
# Please guess a letter or word: develop
# Invalid input. Please guess a letter or a word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# ______p__
#
#
# Guessed letters: p
# Guessed words:
# Please guess a letter or word: d
# Good job! d is in the word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# d_____p__
#
#
# Guessed letters: p d
# Guessed words:
# Please guess a letter or word: e
# Good job! e is in the word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# de_e__pe_
#
#
# Guessed letters: p d e
# Guessed words:
# Please guess a letter or word: v
# Good job! v is in the word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# deve__pe_
#
#
# Guessed letters: p d e v
# Guessed words:
# Please guess a letter or word: l
# Good job! l is in the word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# devel_pe_
#
#
# Guessed letters: p d e v l
# Guessed words:
# Please guess a letter or word: o
# Good job! o is in the word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# develope_
#
#
# Guessed letters: p d e v l o
# Guessed words:
# Please guess a letter or word: r
# Good job! r is in the word.
#
#            ------
#            |    |
#            |    O
#            |   /|\
#            |   / \
#            |
#
# developer
#
#
# Guessed letters: p d e v l o r
# Guessed words:
# Congratulations! You've guessed the word: developer!
